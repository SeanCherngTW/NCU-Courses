# %%
# coding: utf-8
import time
import tensorflow as tf
from datetime import datetime
from functools import partial
from keras.utils.np_utils import to_categorical
from tensorflow.examples.tutorials.mnist import input_data

# %%
mnist = input_data.read_data_sets("../MNIST_data/", one_hot=True)
# Out:
# Extracting ../MNIST_data/train-images-idx3-ubyte.gz
# Extracting ../MNIST_data/train-labels-idx1-ubyte.gz
# Extracting ../MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting ../MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
X_train = mnist.train.images
y_train = mnist.train.labels
X_vali = mnist.validation.images
y_vali = mnist.validation.labels
X_test = mnist.test.images
y_test = mnist.test.labels

# %%
# training = tf.placeholder_with_default(False, shape=(), name='training', dtype=float32)
# batch_norm_layer = partial(tf.layers.batch_normalization, training=training, momentum=0.9)

# %%
def init_input():
    with tf.name_scope('input'):
        X = tf.placeholder('float', [None, 784], name='input_x')
        y = tf.placeholder('float', [None, 10], name='label_y')
    return X, y

# %%
def add_layer(input_dim, output_dim, inputs, name, activation_function=None):
    name_W = 'W_' + name
    name_b = 'b_' + name
    
    with tf.name_scope(name):
        with tf.name_scope('weight'):
#             W = tf.Variable(tf.truncated_normal([input_dim, output_dim], stddev=0.1), name="W")
            W = tf.get_variable(shape=[input_dim, output_dim], initializer=tf.contrib.keras.initializers.he_normal(), name=name_W)
            tf.summary.histogram(name + '/weight', W)
        with tf.name_scope('bias'):
            b = tf.Variable(tf.constant(0.1, shape=[1, output_dim]), name=name_b)
            tf.summary.histogram(name + '/bias', b)
        with tf.name_scope('Wx_plus_b'):
            Wx_plus_b = tf.add(tf.matmul(inputs, W), b)
        if activation_function is None:
            outputs = Wx_plus_b
        else:
            outputs = activation_function(Wx_plus_b)
        tf.summary.histogram(name + '/output', outputs)
        return outputs

# %%
def build_network(X, n, activation, batch_normalization=False):
    h1 = add_layer(input_dim=784, output_dim=n, inputs=X, name='hidden_layer_1', activation_function=activation)
    if batch_normalization:
        h1 = tf.layers.batch_normalization(h1)
        
    h2 = add_layer(input_dim=n, output_dim=n, inputs=h1, name='hidden_layer_2', activation_function=activation)
    if batch_normalization:
        h2 = tf.contrib.layers.batch_norm(h2, center=True, scale=True, is_training=True)
        
    h3 = add_layer(input_dim=n, output_dim=n, inputs=h2, name='hidden_layer_3', activation_function=activation)
    if batch_normalization:
        h3 = tf.contrib.layers.batch_norm(h3, center=True, scale=True, is_training=True)

    h4 = add_layer(input_dim=n, output_dim=n, inputs=h3, name='hidden_layer_4', activation_function=activation)
    if batch_normalization:
        h4 = tf.contrib.layers.batch_norm(h4, center=True, scale=True, is_training=True)

    h5 = add_layer(input_dim=n, output_dim=n, inputs=h4, name='hidden_layer_5', activation_function=activation)
    if batch_normalization:
        h5 = tf.contrib.layers.batch_norm(h5, center=True, scale=True, is_training=True)
        
    y_hat = add_layer(input_dim=n, output_dim=10, inputs=h5, name='output_layer', activation_function=tf.nn.softmax)
    return y_hat

# %%
def init_evaluation(y, y_hat, learning_rate):
    with tf.name_scope('cross_entropy'):
        loss_function = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=y, logits=y_hat))
    tf.summary.scalar('cross_entropy', loss_function)

    with tf.name_scope('train'):
        optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss_function)

    with tf.name_scope('accuracy'):
        with tf.name_scope('correction_prediction'):
            correct_prediction_count = tf.equal(tf.argmax(y, 1), tf.argmax(y_hat, 1))
        with tf.name_scope('accuracy'):
            acc = tf.reduce_mean(tf.cast(correct_prediction_count, 'float'))
    tf.summary.scalar('accuracy', acc)
    
    return loss_function, optimizer, acc

# %%
def DNN(epoch, n_neurons, learning_rate, activation, batch_size, early_stopping, batch_normalization=False, restore_model_name=None):
    tf.reset_default_graph()
    
    training_id = '[n_neurons_%d, learning_rate_%.4f, activation_%s, batch_size_%d, batch_normalization_%s]' % (n_neurons, learning_rate, activation, batch_size, batch_normalization)
    print(training_id)
    training_id += "-" + datetime.utcnow().strftime("%Y%m%d%H%M%S")
    logdir = "tf_logs/{}/".format(training_id)
    
    X, y = init_input()
    y_hat = build_network(X, n_neurons, activation, batch_normalization=batch_normalization)
    loss_function, optimizer, acc = init_evaluation(y, y_hat, learning_rate)
    
    batch = int(mnist.train.num_examples / batch_size)

    vali_loss_list = []
    vali_acc_list = []
    n = 0
    
    saver = tf.train.Saver()
    start_epoch = 0
    
    with tf.Session() as sess:
        if restore_model_name:
            saver.restore(sess, "regular_train/" + restore_model_name)
            start_epoch = int(restore_model_name.split('.')[0].split('_')[-1])
        else:
            sess.run(tf.global_variables_initializer())
            
        merged = tf.summary.merge_all()    
        writer = tf.summary.FileWriter(logdir, sess.graph)
        
        for i in range(start_epoch, epoch):
            for j in range(batch):
                batch_x = X_train[j * batch_size : (j + 1) * batch_size]
                batch_y = y_train[j * batch_size : (j + 1) * batch_size]
                sess.run(optimizer, feed_dict={X: batch_x, y: batch_y})
                
            result = sess.run(merged, feed_dict={X: X_vali, y: y_vali})
            writer.add_summary(result, i + 1)

            vali_loss = sess.run(loss_function, feed_dict={X: X_vali, y: y_vali})
            vali_acc = sess.run(acc, feed_dict={X: X_vali, y: y_vali})
            
            vali_loss_list.append(vali_loss)
            vali_acc_list.append(vali_acc)
            
            file_name = 'regular_training_epoch_%d.ckpt' % (i+1)
            save_path = saver.save(sess, "regular_train/%s/%s" % (training_id, file_name))
            best_vali_acc = max(vali_acc_list)
            best_vali_loss = min(vali_loss_list)
            
            print("Epoch: %2d, Validation loss: %9.4f, Best loss:%9.4f, Accuracy: %.4f, Best Accuracy: %.4f" % (i+1, vali_loss, best_vali_loss, vali_acc, best_vali_acc))    
            
            if vali_acc < best_vali_acc:
#                 print('Early stopping %d' % n)
                n += 1
            else:
                n = 0
                
            if n > early_stopping:
                print('Early Stopping at epoch %d' % i)
                break
        
        file_name = 'final_model'
        save_path = saver.save(sess, "regular_train/%s/%s" %(training_id, file_name))
        print("Model saved in path: %s" % save_path)
        
        test_acc = sess.run(acc, feed_dict={X: X_test, y: y_test})
        print("Final test accuracy: %.4f" % test_acc)

# %%
DNN(epoch=1000, n_neurons=100, learning_rate=0.004, activation=tf.nn.elu, batch_size=400, early_stopping=30, batch_normalization=False)
DNN(epoch=1000, n_neurons=100, learning_rate=0.004, activation=tf.nn.elu, batch_size=400, early_stopping=10, batch_normalization=True)
# Out:
# [n_neurons_100, learning_rate_0.0040, activation_<function elu at 0x1123d70d0>, batch_size_400, batch_normalization_False]
# Epoch:  1, Validation loss:    1.5426, Best loss:   1.5426, Accuracy: 0.9184, Best Accuracy: 0.9184
# Epoch:  2, Validation loss:    1.5400, Best loss:   1.5400, Accuracy: 0.9206, Best Accuracy: 0.9206
# Epoch:  3, Validation loss:    1.5488, Best loss:   1.5400, Accuracy: 0.9126, Best Accuracy: 0.9206
# Epoch:  4, Validation loss:    1.5438, Best loss:   1.5400, Accuracy: 0.9170, Best Accuracy: 0.9206
# Epoch:  5, Validation loss:    1.5324, Best loss:   1.5324, Accuracy: 0.9288, Best Accuracy: 0.9288
# Epoch:  6, Validation loss:    1.5971, Best loss:   1.5324, Accuracy: 0.8642, Best Accuracy: 0.9288
# Epoch:  7, Validation loss:    1.5709, Best loss:   1.5324, Accuracy: 0.8902, Best Accuracy: 0.9288
# Epoch:  8, Validation loss:    1.5619, Best loss:   1.5324, Accuracy: 0.8992, Best Accuracy: 0.9288
# Epoch:  9, Validation loss:    1.5888, Best loss:   1.5324, Accuracy: 0.8724, Best Accuracy: 0.9288
# Epoch: 10, Validation loss:    1.6322, Best loss:   1.5324, Accuracy: 0.8290, Best Accuracy: 0.9288
# Epoch: 11, Validation loss:    1.6184, Best loss:   1.5324, Accuracy: 0.8428, Best Accuracy: 0.9288
# Epoch: 12, Validation loss:    1.6706, Best loss:   1.5324, Accuracy: 0.7904, Best Accuracy: 0.9288
# Epoch: 13, Validation loss:    1.6674, Best loss:   1.5324, Accuracy: 0.7938, Best Accuracy: 0.9288
# Epoch: 14, Validation loss:    1.7760, Best loss:   1.5324, Accuracy: 0.6850, Best Accuracy: 0.9288
# Epoch: 15, Validation loss:    1.8233, Best loss:   1.5324, Accuracy: 0.6378, Best Accuracy: 0.9288
# Epoch: 16, Validation loss:    1.7014, Best loss:   1.5324, Accuracy: 0.7596, Best Accuracy: 0.9288
# Epoch: 17, Validation loss:    1.7629, Best loss:   1.5324, Accuracy: 0.6984, Best Accuracy: 0.9288
# Epoch: 18, Validation loss:    2.1238, Best loss:   1.5324, Accuracy: 0.3374, Best Accuracy: 0.9288
# Epoch: 19, Validation loss:    1.8723, Best loss:   1.5324, Accuracy: 0.5888, Best Accuracy: 0.9288
# Epoch: 20, Validation loss:    1.7945, Best loss:   1.5324, Accuracy: 0.6666, Best Accuracy: 0.9288
# Epoch: 21, Validation loss:    1.8499, Best loss:   1.5324, Accuracy: 0.6112, Best Accuracy: 0.9288
# Epoch: 22, Validation loss:    1.7920, Best loss:   1.5324, Accuracy: 0.6692, Best Accuracy: 0.9288
# Epoch: 23, Validation loss:    1.8077, Best loss:   1.5324, Accuracy: 0.6534, Best Accuracy: 0.9288
# Epoch: 24, Validation loss:    1.8597, Best loss:   1.5324, Accuracy: 0.6014, Best Accuracy: 0.9288
# Epoch: 25, Validation loss:    1.8731, Best loss:   1.5324, Accuracy: 0.5880, Best Accuracy: 0.9288
# Epoch: 26, Validation loss:    1.9261, Best loss:   1.5324, Accuracy: 0.5350, Best Accuracy: 0.9288
# Epoch: 27, Validation loss:    1.8653, Best loss:   1.5324, Accuracy: 0.5958, Best Accuracy: 0.9288
# Epoch: 28, Validation loss:    1.9543, Best loss:   1.5324, Accuracy: 0.5068, Best Accuracy: 0.9288
# Epoch: 29, Validation loss:    1.8559, Best loss:   1.5324, Accuracy: 0.6052, Best Accuracy: 0.9288
# Epoch: 30, Validation loss:    1.9265, Best loss:   1.5324, Accuracy: 0.5346, Best Accuracy: 0.9288
# Epoch: 31, Validation loss:    1.8463, Best loss:   1.5324, Accuracy: 0.6148, Best Accuracy: 0.9288
# Epoch: 32, Validation loss:    1.8130, Best loss:   1.5324, Accuracy: 0.6482, Best Accuracy: 0.9288
# Epoch: 33, Validation loss:    1.7733, Best loss:   1.5324, Accuracy: 0.6878, Best Accuracy: 0.9288
# Epoch: 34, Validation loss:    1.8575, Best loss:   1.5324, Accuracy: 0.6036, Best Accuracy: 0.9288
# Epoch: 35, Validation loss:    1.8107, Best loss:   1.5324, Accuracy: 0.6504, Best Accuracy: 0.9288
# Epoch: 36, Validation loss:    1.8069, Best loss:   1.5324, Accuracy: 0.6542, Best Accuracy: 0.9288
# Early Stopping at epoch 35
# Model saved in path: regular_train/[n_neurons_100, learning_rate_0.0040, activation_<function elu at 0x1123d70d0>, batch_size_400, batch_normalization_False]-20180419094327/final_model
# Final test accuracy: 0.6386
# [n_neurons_100, learning_rate_0.0040, activation_<function elu at 0x1123d70d0>, batch_size_400, batch_normalization_True]
# Epoch:  1, Validation loss:    1.5144, Best loss:   1.5144, Accuracy: 0.9504, Best Accuracy: 0.9504
# Epoch:  2, Validation loss:    1.5069, Best loss:   1.5069, Accuracy: 0.9558, Best Accuracy: 0.9558
# Epoch:  3, Validation loss:    1.5029, Best loss:   1.5029, Accuracy: 0.9610, Best Accuracy: 0.9610
# Epoch:  4, Validation loss:    1.4998, Best loss:   1.4998, Accuracy: 0.9630, Best Accuracy: 0.9630
# Epoch:  5, Validation loss:    1.4938, Best loss:   1.4938, Accuracy: 0.9686, Best Accuracy: 0.9686
# Epoch:  6, Validation loss:    1.4911, Best loss:   1.4911, Accuracy: 0.9698, Best Accuracy: 0.9698
# Epoch:  7, Validation loss:    1.4890, Best loss:   1.4890, Accuracy: 0.9724, Best Accuracy: 0.9724
# Epoch:  8, Validation loss:    1.4957, Best loss:   1.4890, Accuracy: 0.9656, Best Accuracy: 0.9724
# Epoch:  9, Validation loss:    1.4901, Best loss:   1.4890, Accuracy: 0.9716, Best Accuracy: 0.9724
# Epoch: 10, Validation loss:    1.4858, Best loss:   1.4858, Accuracy: 0.9754, Best Accuracy: 0.9754
# Epoch: 11, Validation loss:    1.4877, Best loss:   1.4858, Accuracy: 0.9742, Best Accuracy: 0.9754
# Epoch: 12, Validation loss:    1.4886, Best loss:   1.4858, Accuracy: 0.9734, Best Accuracy: 0.9754
# Epoch: 13, Validation loss:    1.4906, Best loss:   1.4858, Accuracy: 0.9702, Best Accuracy: 0.9754
# Epoch: 14, Validation loss:    1.4870, Best loss:   1.4858, Accuracy: 0.9742, Best Accuracy: 0.9754
# Epoch: 15, Validation loss:    1.4897, Best loss:   1.4858, Accuracy: 0.9720, Best Accuracy: 0.9754
# Epoch: 16, Validation loss:    1.4911, Best loss:   1.4858, Accuracy: 0.9708, Best Accuracy: 0.9754
# Epoch: 17, Validation loss:    1.4903, Best loss:   1.4858, Accuracy: 0.9708, Best Accuracy: 0.9754
# Epoch: 18, Validation loss:    1.4884, Best loss:   1.4858, Accuracy: 0.9724, Best Accuracy: 0.9754
# Epoch: 19, Validation loss:    1.4899, Best loss:   1.4858, Accuracy: 0.9710, Best Accuracy: 0.9754
# Epoch: 20, Validation loss:    1.4871, Best loss:   1.4858, Accuracy: 0.9746, Best Accuracy: 0.9754
# Epoch: 21, Validation loss:    1.4861, Best loss:   1.4858, Accuracy: 0.9758, Best Accuracy: 0.9758
# Epoch: 22, Validation loss:    1.4900, Best loss:   1.4858, Accuracy: 0.9714, Best Accuracy: 0.9758
# Epoch: 23, Validation loss:    1.4902, Best loss:   1.4858, Accuracy: 0.9710, Best Accuracy: 0.9758
# Epoch: 24, Validation loss:    1.4878, Best loss:   1.4858, Accuracy: 0.9736, Best Accuracy: 0.9758
# Epoch: 25, Validation loss:    1.4852, Best loss:   1.4852, Accuracy: 0.9758, Best Accuracy: 0.9758
# Epoch: 26, Validation loss:    1.4854, Best loss:   1.4852, Accuracy: 0.9756, Best Accuracy: 0.9758
# Epoch: 27, Validation loss:    1.4862, Best loss:   1.4852, Accuracy: 0.9748, Best Accuracy: 0.9758
# Epoch: 28, Validation loss:    1.4863, Best loss:   1.4852, Accuracy: 0.9742, Best Accuracy: 0.9758
# Epoch: 29, Validation loss:    1.4844, Best loss:   1.4844, Accuracy: 0.9768, Best Accuracy: 0.9768
# Epoch: 30, Validation loss:    1.4856, Best loss:   1.4844, Accuracy: 0.9756, Best Accuracy: 0.9768
# Epoch: 31, Validation loss:    1.4842, Best loss:   1.4842, Accuracy: 0.9764, Best Accuracy: 0.9768
# Epoch: 32, Validation loss:    1.4839, Best loss:   1.4839, Accuracy: 0.9776, Best Accuracy: 0.9776
# Epoch: 33, Validation loss:    1.4884, Best loss:   1.4839, Accuracy: 0.9728, Best Accuracy: 0.9776
# Epoch: 34, Validation loss:    1.4853, Best loss:   1.4839, Accuracy: 0.9756, Best Accuracy: 0.9776
# Epoch: 35, Validation loss:    1.4835, Best loss:   1.4835, Accuracy: 0.9776, Best Accuracy: 0.9776
# Epoch: 36, Validation loss:    1.4888, Best loss:   1.4835, Accuracy: 0.9726, Best Accuracy: 0.9776
# Epoch: 37, Validation loss:    1.4884, Best loss:   1.4835, Accuracy: 0.9724, Best Accuracy: 0.9776
# Epoch: 38, Validation loss:    1.4855, Best loss:   1.4835, Accuracy: 0.9754, Best Accuracy: 0.9776
# Epoch: 39, Validation loss:    1.4869, Best loss:   1.4835, Accuracy: 0.9744, Best Accuracy: 0.9776
# Epoch: 40, Validation loss:    1.4862, Best loss:   1.4835, Accuracy: 0.9746, Best Accuracy: 0.9776
# Epoch: 41, Validation loss:    1.4842, Best loss:   1.4835, Accuracy: 0.9766, Best Accuracy: 0.9776
# Epoch: 42, Validation loss:    1.4854, Best loss:   1.4835, Accuracy: 0.9760, Best Accuracy: 0.9776
# Epoch: 43, Validation loss:    1.4856, Best loss:   1.4835, Accuracy: 0.9754, Best Accuracy: 0.9776
# Epoch: 44, Validation loss:    1.4859, Best loss:   1.4835, Accuracy: 0.9744, Best Accuracy: 0.9776
# Epoch: 45, Validation loss:    1.4843, Best loss:   1.4835, Accuracy: 0.9768, Best Accuracy: 0.9776
# Epoch: 46, Validation loss:    1.4892, Best loss:   1.4835, Accuracy: 0.9722, Best Accuracy: 0.9776
# Early Stopping at epoch 45
# Model saved in path: regular_train/[n_neurons_100, learning_rate_0.0040, activation_<function elu at 0x1123d70d0>, batch_size_400, batch_normalization_True]-20180419094411/final_model
# Final test accuracy: 0.9727

# %%
# %save MNIST_batch_normalization.py 60-69
# Out:
# The following commands were written to file `MNIST_batch_normalization.py`:
#
# import time
# import tensorflow as tf
# from datetime import datetime
# from functools import partial
# from keras.utils.np_utils import to_categorical
# from tensorflow.examples.tutorials.mnist import input_data
# mnist = input_data.read_data_sets("../MNIST_data/", one_hot=True)
# X_train = mnist.train.images
# y_train = mnist.train.labels
# X_vali = mnist.validation.images
# y_vali = mnist.validation.labels
# X_test = mnist.test.images
# y_test = mnist.test.labels
# # training = tf.placeholder_with_default(False, shape=(), name='training', dtype=float32)
# # batch_norm_layer = partial(tf.layers.batch_normalization, training=training, momentum=0.9)
# def init_input():
#     with tf.name_scope('input'):
#         X = tf.placeholder('float', [None, 784], name='input_x')
#         y = tf.placeholder('float', [None, 10], name='label_y')
#     return X, y
# def add_layer(input_dim, output_dim, inputs, name, activation_function=None):
#     name_W = 'W_' + name
#     name_b = 'b_' + name
#
#     with tf.name_scope(name):
#         with tf.name_scope('weight'):
# #             W = tf.Variable(tf.truncated_normal([input_dim, output_dim], stddev=0.1), name="W")
#             W = tf.get_variable(shape=[input_dim, output_dim], initializer=tf.contrib.keras.initializers.he_normal(), name=name_W)
#             tf.summary.histogram(name + '/weight', W)
#         with tf.name_scope('bias'):
#             b = tf.Variable(tf.constant(0.1, shape=[1, output_dim]), name=name_b)
#             tf.summary.histogram(name + '/bias', b)
#         with tf.name_scope('Wx_plus_b'):
#             Wx_plus_b = tf.add(tf.matmul(inputs, W), b)
#         if activation_function is None:
#             outputs = Wx_plus_b
#         else:
#             outputs = activation_function(Wx_plus_b)
#         tf.summary.histogram(name + '/output', outputs)
#         return outputs
# def build_network(X, n, activation, batch_normalization=False):
#     h1 = add_layer(input_dim=784, output_dim=n, inputs=X, name='hidden_layer_1', activation_function=activation)
#     if batch_normalization:
#         h1 = tf.layers.batch_normalization(h1)
#
#     h2 = add_layer(input_dim=n, output_dim=n, inputs=h1, name='hidden_layer_2', activation_function=activation)
#     if batch_normalization:
#         h2 = tf.contrib.layers.batch_norm(h2, center=True, scale=True, is_training=True)
#
#     h3 = add_layer(input_dim=n, output_dim=n, inputs=h2, name='hidden_layer_3', activation_function=activation)
#     if batch_normalization:
#         h3 = tf.contrib.layers.batch_norm(h3, center=True, scale=True, is_training=True)
#
#     h4 = add_layer(input_dim=n, output_dim=n, inputs=h3, name='hidden_layer_4', activation_function=activation)
#     if batch_normalization:
#         h4 = tf.contrib.layers.batch_norm(h4, center=True, scale=True, is_training=True)
#
#     h5 = add_layer(input_dim=n, output_dim=n, inputs=h4, name='hidden_layer_5', activation_function=activation)
#     if batch_normalization:
#         h5 = tf.contrib.layers.batch_norm(h5, center=True, scale=True, is_training=True)
#
#     y_hat = add_layer(input_dim=n, output_dim=10, inputs=h5, name='output_layer', activation_function=tf.nn.softmax)
#     return y_hat
# def init_evaluation(y, y_hat, learning_rate):
#     with tf.name_scope('cross_entropy'):
#         loss_function = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=y, logits=y_hat))
#     tf.summary.scalar('cross_entropy', loss_function)
#
#     with tf.name_scope('train'):
#         optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss_function)
#
#     with tf.name_scope('accuracy'):
#         with tf.name_scope('correction_prediction'):
#             correct_prediction_count = tf.equal(tf.argmax(y, 1), tf.argmax(y_hat, 1))
#         with tf.name_scope('accuracy'):
#             acc = tf.reduce_mean(tf.cast(correct_prediction_count, 'float'))
#     tf.summary.scalar('accuracy', acc)
#
#     return loss_function, optimizer, acc
# def DNN(epoch, n_neurons, learning_rate, activation, batch_size, early_stopping, batch_normalization=False, restore_model_name=None):
#     tf.reset_default_graph()
#
#     training_id = '[n_neurons_%d, learning_rate_%.4f, activation_%s, batch_size_%d, batch_normalization_%s]' % (n_neurons, learning_rate, activation, batch_size, batch_normalization)
#     print(training_id)
#     training_id += "-" + datetime.utcnow().strftime("%Y%m%d%H%M%S")
#     logdir = "tf_logs/{}/".format(training_id)
#
#     X, y = init_input()
#     y_hat = build_network(X, n_neurons, activation, batch_normalization=batch_normalization)
#     loss_function, optimizer, acc = init_evaluation(y, y_hat, learning_rate)
#
#     batch = int(mnist.train.num_examples / batch_size)
#
#     vali_loss_list = []
#     vali_acc_list = []
#     n = 0
#
#     saver = tf.train.Saver()
#     start_epoch = 0
#
#     with tf.Session() as sess:
#         if restore_model_name:
#             saver.restore(sess, "regular_train/" + restore_model_name)
#             start_epoch = int(restore_model_name.split('.')[0].split('_')[-1])
#         else:
#             sess.run(tf.global_variables_initializer())
#
#         merged = tf.summary.merge_all()
#         writer = tf.summary.FileWriter(logdir, sess.graph)
#
#         for i in range(start_epoch, epoch):
#             for j in range(batch):
#                 batch_x = X_train[j * batch_size : (j + 1) * batch_size]
#                 batch_y = y_train[j * batch_size : (j + 1) * batch_size]
#                 sess.run(optimizer, feed_dict={X: batch_x, y: batch_y})
#
#             result = sess.run(merged, feed_dict={X: X_vali, y: y_vali})
#             writer.add_summary(result, i + 1)
#
#             vali_loss = sess.run(loss_function, feed_dict={X: X_vali, y: y_vali})
#             vali_acc = sess.run(acc, feed_dict={X: X_vali, y: y_vali})
#
#             vali_loss_list.append(vali_loss)
#             vali_acc_list.append(vali_acc)
#
#             file_name = 'regular_training_epoch_%d.ckpt' % (i+1)
#             save_path = saver.save(sess, "regular_train/%s/%s" % (training_id, file_name))
#             best_vali_acc = max(vali_acc_list)
#             best_vali_loss = min(vali_loss_list)
#
#             print("Epoch: %2d, Validation loss: %9.4f, Best loss:%9.4f, Accuracy: %.4f, Best Accuracy: %.4f" % (i+1, vali_loss, best_vali_loss, vali_acc, best_vali_acc))
#
#             if vali_acc < best_vali_acc:
# #                 print('Early stopping %d' % n)
#                 n += 1
#             else:
#                 n = 0
#
#             if n > early_stopping:
#                 print('Early Stopping at epoch %d' % i)
#                 break
#
#         file_name = 'final_model'
#         save_path = saver.save(sess, "regular_train/%s/%s" %(training_id, file_name))
#         print("Model saved in path: %s" % save_path)
#
#         test_acc = sess.run(acc, feed_dict={X: X_test, y: y_test})
#         print("Final test accuracy: %.4f" % test_acc)
# DNN(epoch=1000, n_neurons=100, learning_rate=0.004, activation=tf.nn.elu, batch_size=400, early_stopping=30, batch_normalization=False)
# DNN(epoch=1000, n_neurons=100, learning_rate=0.004, activation=tf.nn.elu, batch_size=400, early_stopping=10, batch_normalization=True)
